# %%
from transformers import pipeline
# image_path = "https://farm5.staticflickr.com/4007/4322154488_997e69e4cf_z.jpg"
# image_path = "C:\\Users\\liuja\\Desktop\\School\\2024-Spring-Junior\\CS 445\\Final Project CS445\\CS445Final\\waldo samples\\waldo_cropped.JPG"
pipe = pipeline("image-segmentation", model="briaai/RMBG-1.4", trust_remote_code=True)

# %%
image_path = "C:\\Users\\liuja\\Desktop\\School\\2024-Spring-Junior\\CS 445\\Final Project CS445\\CS445Final\\samples\\man.JPG"
pillow_mask = pipe(image_path, return_mask = True) # outputs a pillow mask
pillow_image = pipe(image_path) # applies mask on input and returns a pillow image

# %%
import matplotlib.pyplot as plt 
display(pillow_mask)
display(pillow_image)
# Out:
# <PIL.Image.Image image mode=L size=119x298 at 0x24B7282E220>
# <PIL.Image.Image image mode=RGBA size=119x298 at 0x24B700B98E0>
